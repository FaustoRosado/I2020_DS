# %% [markdown]
# <div style="background: #000;
#             color: #FFF;
#             margin: 0px;
#                 padding: 10px 0px 20px 0px;
#             text-align: center;
#                 ">
#     <h1>Week 9 - Class 1 - Lab</h1>
# </div>

# %% [markdown]
# # Question 1:
#
# What data would you like to work on for your final project and why?

# %% [markdown]
# Would like to pull homeless data from NYC Open Data and though we are not visualizing, use python library or front end JS library like D3 to visualize it using interactive charts.

# %% [markdown]
# # Exercise 1
#
# Get flask installed on your machine and get a simple web application running with one route that returns data of your choosing.

# %%
# submit your *.py file with your this lab's submission

# %% [markdown]
# # Exercise 2
#
# Create a flask application with the following routes:
# 1. route that takes an integer as input and returns the square root. (`app.route('/sqrt/<input>`).
# 2. route that takes a username and returns a message (`app.route('/user/<username>`).
# 3. route that returns some information about the request.

# %%
# submit your *.py file with this lab's submission.

# %% [markdown]
# # Exercise 3
#
# Find a data source you would like to do your final project on (e.g. election or covid data). Write a python  script that scrapes the data from that source.

# %%
# submit your *.py file with this lab's submission.

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.coalitionforthehomeless.org/basic-facts-about-\
       homelessness-new-york-city-data-and-charts/'
req = requests.get(url)

soup = BeautifulSoup(req.content)

if __name__ == '__main__':    
    print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lte IE 8 ]><html class="oldie" lang="en-US"><![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html lang="en-US">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Basic Facts About Homelessness: New York City Data and Charts - Coalition For The Homeless
#   </title>
#   <meta content="Basic Facts About Homelessness: New York City Data and Charts - Coalition For The Homeless" name="title"/>
#   <meta content="Basic Facts About Homelessness: New York City Data and Charts - Coalition For The Homeless" property="og:title">
#    <meta content="yGdMQrvESCS9qSBddQGkqkZYuDB0eRRklRonUTYLFS4" name="google-site-verification">
#     <meta content="This page provides up-to-date statistics and charts about homelessness in New York City. Here you can ..." property="og:description">
#      <meta content="telephone=no" name="format-detection"/>
# ...
